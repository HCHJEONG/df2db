# %%
import pandas as pd
import glob
import sqlalchemy
## from sqlalchemy.ext.declarative import declarative_base

urls = glob.glob("C:/Users/hcjeo/VSCodeProjects/web2df/for_check/df_corpus_0.xlsx")
engine = sqlalchemy.create_engine("mariadb+mariadbconnector://{user}:{pw}@localhost:3307/{db}".format(user='root', pw='3330', db='test'))

# dtype={'applicable_acts': sqlalchemy.types.VARCHAR(100),
# 		'stock_cd': sqlalchemy.types.VARCHAR(100),
# 		'stock_date': sqlalchemy.types.VARCHAR(100),
# 		'open': sqlalchemy.types.DECIMAL(24, 6),
# 		'high': sqlalchemy.types.DECIMAL(24, 6),
# 		'low': sqlalchemy.types.DECIMAL(24, 6),
# 		'close': sqlalchemy.types.DECIMAL(24, 6),
# 		'diff': sqlalchemy.types.DECIMAL(24, 6),
# 		'volume': sqlalchemy.types.DECIMAL(24, 6),
# 		'last_update': sqlalchemy.DateTime()}

df = pd.read_excel(urls[0])

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                50 non-null     int64
#  1   case_txt_in_file          50 non-null     object
#  2   case_full_no              50 non-null     object
#  3   case_official_name        50 non-null     object
#  4   case_unofficial_name      1 non-null      object
#  5   citedPlace                50 non-null     object
#  6   decision_items            50 non-null     object
#  7   decision_gists            35 non-null     object
#  8   main_decision             50 non-null     object
#  9   reasoning                 50 non-null     object
#  10  case_comment              14 non-null     object
#  11  related_articles          41 non-null     object
#  12  applicable_acts           49 non-null     object
# ...

# %%
print(type(engine))
df.to_sql(name="cor2tbl_", con=engine) # name은 table name
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\.conda\envs\lawboto\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1749                 if not evt_handled:
# -> 1750                     self.dialect.do_executemany(
#    1751                         cursor, statement, parameters, context
#
# ~\.conda\envs\lawboto\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     713     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 714         cursor.executemany(statement, parameters)
#     715
#
# OperationalError: Incorrect string value: '\xEC\x84\xA0\xEA\xB3\xA0...' for column 'case_txt_in_file' at row 1
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
dframe = []
for i in range(len(df.index)):
    dframe.append(df.iloc[i])

# %%
temp = pd.DataFrame(dframe[0])
print(type(temp))
print(temp)

# %%
temp.to_sql(name="cor2tbl_", con=engine, if_exists='append') # name은 table name

# %%
for data in dframe:
    with engine.connect() as connection:
        data.to_sql(name="cor2tbl_", con=connection, if_exists='append', index=False) # name은 table name
