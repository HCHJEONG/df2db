# %%
import pandas as pd
import glob

urls = glob.glob("C:/Users/hcjeo/VSCodeProjects/web2df/for_check/df_corpus_0.xlsx")
df = pd.read_excel(urls[0])
# print(df.info())

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import declarative_base
from sqlalchemy.orm import scoped_session, sessionmaker
from sqlalchemy import Column, Integer, String, DateTime

engine = create_engine("mariadb+mariadbconnector://{user}:{pw}@127.0.0.1:3306/{db}".format(user='root', pw='3330', db='test'))
db_session = scoped_session(sessionmaker(autocommit=False, autoflush=False, bind=engine))
Base = declarative_base() 
Base.query = db_session.query_property()

class TbTest(Base): 

    __tablename__ = 'tbTable' 
    id = Column(Integer, primary_key=True) 
    datetime = Column(DateTime) 
    string = Column(String(250)) 

    def __init__(self, datetime, string): 
        self.datetime = datetime 
        self.string = string 

    def __repr__(self): 
        return "<TbTest('%d', '%s', '%s'>" %(self.id, str(self.datetime), self.string)

def init_db():
    Base.metadata.create_all(engine)

def show_tables(): 
    queries = db_session.query(TbTest) 
    entries = [dict(id=q.id, datetime=q.datetime, string=q.string) for q in queries] 
    print (entries)

def add_entry(datetime, string): 
    t = TbTest(datetime, string) 
    db_session.add(t) 
    db_session.commit() 

def delete_entry(datetime, string): 
    db_session.query(TbTest).filter(TbTest.datetime==datetime, TbTest.string==string).delete() 
    db_session.commit() 
    
def main(): 
    add_entry("2015-02-06 09:00:05", "test1") 
    show_tables()
    # delete_entry("2015-02-06 09:00:05","test1") 
    show_tables()
    db_session.close() 
    
if __name__ == "__main__" : 
    
    db_session.close() 
    init_db()
    main()
# Out:
# [{'id': 3, 'datetime': datetime.datetime(2015, 2, 6, 9, 0, 5), 'string': 'test1'}]
# [{'id': 3, 'datetime': datetime.datetime(2015, 2, 6, 9, 0, 5), 'string': 'test1'}]

# %%
import sqlalchemy

metadata = sqlalchemy.MetaData()
table = sqlalchemy.Table('tbTable', metadata, autoload=True, autoload_with=engine)
print(table.columns.keys())
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\.conda\envs\lawboto\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1769                 if not evt_handled:
# -> 1770                     self.dialect.do_execute(
#    1771                         cursor, statement, parameters, context
#
# ~\.conda\envs\lawboto\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# ProgrammingError: Table 'mysql.tbtable' doesn't exist
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# ...
